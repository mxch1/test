# %% [markdown]
# ## Module submission header
# ### Submission preparation instructions
# _Completion of this header is mandatory, subject to a 2-point deduction to the assignment._ Only add plain text in the designated areas, i.e., replacing the relevant 'NA's. You must fill out all group member Names and Drexel email addresses in the below markdown list, under header __Module submission group__. It is required to fill out descriptive notes pertaining to any tutoring support received in the completion of this submission under the __Additional submission comments__ section at the bottom of the header. If no tutoring support was received, leave NA in place. You may as well list other optional comments pertaining to the submission at bottom. _Any distruption of this header's formatting will make your group liable to the 2-point deduction._
#
# ### Module submission group
# - Group member 1
#     - Name: max bezahler
#     - Email: meb25@drexel.edu
# - Group member 2
#     - Name: NA
#     - Email: NA
# - Group member 3
#     - Name: NA
#     - Email: NA
# - Group member 4
#     - Name: NA
#     - Email: NA
#
# ### Additional submission comments
# - Tutoring support received: None
# - Other (other): Stackoverflow where noted!

# %% [markdown]
# # Assignment group 1: Textual feature extraction and numerical comparison

# %% [markdown]
# ## Module A _(35 points)_ Processing numeric data

# %% [markdown]
# __A1.__ _(3 points)_ In this problem, you will be working with the demographics data from The Henry J. Kaiser Family Foundation (https://www.kff.org/) including the population of 52 locations (50 states, District of Columbia, and Puerto Rico) based on race, gender, age, and the number of adults with and without children. This data is obtained from the Census Bureau’s American Community Survey (ACS). The data is stored in a `csv` file format located in the attached `data` directory. Read the `data/demographics.csv` file into a `pandas` dataframe and print the dimensionality (using `.shape` method) and the name of the features of the dataframe.

# %%
# !pip install pandas

# %%
import pandas as pd
# make a dataframe 
df = pd.read_csv(r".\data\demographics.csv")  #file is comma separted pd default so no delimiter specified 
df.info()  #really gives best features regarding the data frame because completenesss
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 18 columns):
# Location                                     52 non-null object
# Male                                         52 non-null int64
# Female                                       52 non-null int64
# Adults_with_Children                         52 non-null int64
# Adults_with_No_Children                      52 non-null int64
# White                                        52 non-null int64
# Black                                        51 non-null float64
# Hispanic                                     52 non-null int64
# Asian                                        51 non-null float64
# American_Indian_or_Alaska_Native             49 non-null float64
# Native_Hawaiian_or_Other_Pacific_Islander    19 non-null float64
# Two_Or_More_Races                            51 non-null float64
# Age0_18                                      52 non-null int64
# ...

# %%
#https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.info.html?highlight=info#pandas.DataFrame.info
df.memory_usage(deep=True)
# Out:
# Index                                         128
# Location                                     3417
# Male                                          416
# Female                                        416
# Adults_with_Children                          416
# Adults_with_No_Children                       416
# White                                         416
# Black                                         416
# Hispanic                                      416
# Asian                                         416
# American_Indian_or_Alaska_Native              416
# Native_Hawaiian_or_Other_Pacific_Islander     416
# Two_Or_More_Races                             416
# Age0_18                                       416
# Age_19_25                                     416
# Age_26_34                                     416
# Age_35_54                                     416
# Age_55_64                                     416
# Age_65_plus                                   416
# ...

# %%
print("Features of the dataset ")
x = df.shape 
print('rows:',x[0], 'cols:', x[1])
# Out:
# Features of the dataset
# rows: 52 cols: 18

# %%
cols = df.columns.tolist()

for i in cols:
    print(i)
# Out:
# Location
# Male
# Female
# Adults_with_Children
# Adults_with_No_Children
# White
# Black
# Hispanic
# Asian
# American_Indian_or_Alaska_Native
# Native_Hawaiian_or_Other_Pacific_Islander
# Two_Or_More_Races
# Age0_18
# Age_19_25
# Age_26_34
# Age_35_54
# Age_55_64
# Age_65_plus

# %%
df.dtypes  #https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.dtypes.html
# Out:
# Location                                      object
# Male                                           int64
# Female                                         int64
# Adults_with_Children                           int64
# Adults_with_No_Children                        int64
# White                                          int64
# Black                                        float64
# Hispanic                                       int64
# Asian                                        float64
# American_Indian_or_Alaska_Native             float64
# Native_Hawaiian_or_Other_Pacific_Islander    float64
# Two_Or_More_Races                            float64
# Age0_18                                        int64
# Age_19_25                                      int64
# Age_26_34                                    float64
# Age_35_54                                      int64
# Age_55_64                                      int64
# Age_65_plus                                    int64
# ...

# %% [markdown]
# __A2.__ _(2 points)_ To gain a better insight into the dataframe, show the head and tail of the dataframe (using the `.head()` and `.tail()` methods).

# %%
df.head() #default to 5 values
# Out:
#      Location      Male    Female  Adults_with_Children  \
# 0     Alabama   2284900   2456500                878300
# 1      Alaska    364500    345600                153600
# 2     Arizona   3363200   3478100               1322700
# 3    Arkansas   1422700   1487200                602000
# 4  California  19113000  19600800               7955200
#
#    Adults_with_No_Children     White      Black  Hispanic      Asian  \
# 0                  1941300   3119100  1259900.0    195700    63800.0
# 1                   283800    433000    18000.0     47400    46600.0
# 2                  2646700   3761600   270200.0   2143400   220300.0
# 3                  1096800   2109200   434100.0    220300    48100.0
# 4                 15981800  14305700  2061600.0  15194400  5598000.0
#
#    American_Indian_or_Alaska_Native  \
# 0                           19800.0
# 1                           95500.0
# 2                          261300.0
# 3                           13500.0
# ...

# %%
df.tail(8)
# Out:
#          Location     Male   Female  Adults_with_Children  \
# 44           Utah  1529300  1518100                734000
# 45        Vermont   295800   304400                113000
# 46       Virginia  3937000  4203700               1667100
# 47     Washington  3589700  3650100               1522400
# 48  West Virginia   863400   898700                322100
# 49      Wisconsin  2792400  2850600               1161900
# 50        Wyoming   286600   276700                118200
# 51    Puerto Rico  1570300  1734500                543200
#
#     Adults_with_No_Children    White      Black  Hispanic     Asian  \
# 44                  1023200  2392300    33000.0    425000   74200.0
# 45                   253100   559000     7000.0     10400   10300.0
# 46                  3302200  5039200  1507600.0    758500  533400.0
# 47                  2920700  4976100   246900.0    916000  617900.0
# 48                   714100  1631600    64300.0     20400   14200.0
# ...

# %% [markdown]
# __A3.__ _(5 points)_ As you can see, there is no `total` population column in this dataframe for each location. Therefore, create a new column which shows the summation of `Male` and `Female` populations.
#
# The `pandas` package provides a `.describe()` method which gives a descriptive summary of the desired column(s) (such as mean, standard deviation, min, and max values). Print these statistics for the column `total` which you just created. Then, compare the average population of locations obtained from `.describe()` method with the output of the `mean` method of `numpy` package. Are they the same?

# %%
#options display 
#https://pandas.pydata.org/pandas-docs/stable/user_guide/options.html?highlight=options%20display%20float_format 
pd.set_option('precision', 10)

# %%
df.dtypes #get col names...
# Out:
# Location                                      object
# Male                                           int64
# Female                                         int64
# Adults_with_Children                           int64
# Adults_with_No_Children                        int64
# White                                          int64
# Black                                        float64
# Hispanic                                       int64
# Asian                                        float64
# American_Indian_or_Alaska_Native             float64
# Native_Hawaiian_or_Other_Pacific_Islander    float64
# Two_Or_More_Races                            float64
# Age0_18                                        int64
# Age_19_25                                      int64
# Age_26_34                                    float64
# Age_35_54                                      int64
# Age_55_64                                      int64
# Age_65_plus                                    int64
# ...

# %%
pd.set_eng_float_format(accuracy=2, use_eng_prefix=True)

# %%
df['total'] = df['Male']+ df['Female']

# %%
df['total'].describe()  #not great 
#https://pandas.pydata.org/pandas-docs/stable/user_guide/options.html?highlight=options%20display%20float_format
# Out:
# count           52.00
# mean     6,160,138.46
# std      7,092,524.58
# min        563,300.00
# 25%      1,742,100.00
# 50%      4,185,050.00
# 75%      6,940,925.00
# max     38,713,800.00
# Name: total, dtype: float64

# %%
#better formatting 
#https://stackoverflow.com/questions/20937538/how-to-display-pandas-dataframe-of-floats-using-a-format-string-for-columns
pd.options.display.float_format = '{:,.2f}'.format #we want .2 for mean and std

# %%
df['total'].describe()
# Out:
# count           52.00
# mean     6,160,138.46
# std      7,092,524.58
# min        563,300.00
# 25%      1,742,100.00
# 50%      4,185,050.00
# 75%      6,940,925.00
# max     38,713,800.00
# Name: total, dtype: float64

# %% [markdown]
# __A4:__ _(5 points)_ Find the locations with the minimum and maximum populations.

# %%
df['total'].max()
# Out:
# 38713800

# %%
df['total'].min()
# Out:
# 563300

# %%
df[df['total']== min(df['total'])][['Location','total']]
# Out:
#    Location   total
# 50  Wyoming  563300

# %% [markdown]
# __A5.__ _(5 points)_ In this part, we are looking at two columns, `Adults_with_Children` and `Adults_with_No_Children`.
# It seems that the populations in these two columns do not include the children (aged younger than 18 years), and older adults (aged older than 64 years). Confirm this hypothesis for `Pennsylvania`, `Colorado`, and `Georgia` that summation of these two columns equal the summation of the population of all age-groups when two `Age0_18` and `Age_65_plus` columns are excluded (For doing that, you may create a new column `total_adults_age_groups` and compare that with the summation of `Adults_with_Children` and `Adults_with_No_Children`).

# %%
#check the column names 
df.dtypes
# Out:
# Location                                      object
# Male                                           int64
# Female                                         int64
# Adults_with_Children                           int64
# Adults_with_No_Children                        int64
# White                                          int64
# Black                                        float64
# Hispanic                                       int64
# Asian                                        float64
# American_Indian_or_Alaska_Native             float64
# Native_Hawaiian_or_Other_Pacific_Islander    float64
# Two_Or_More_Races                            float64
# Age0_18                                        int64
# Age_19_25                                      int64
# Age_26_34                                    float64
# Age_35_54                                      int64
# Age_55_64                                      int64
# Age_65_plus                                    int64
# ...

# %%
#make a list with the right columns 
# Here, create a new column 'total_adults_age_groups' to represent the total adults population of each location
total_adults_age_groups = ['Age_19_25', 'Age_26_34', 'Age_35_54', 'Age_55_64']

# %%
df[total_adults_age_groups].head(3) #
# Out:
#    Age_19_25  Age_26_34  Age_35_54  Age_55_64
# 0     430500 536,200.00    1207200     645600
# 1      63500  97,900.00     183600      92400
# 2     637200 815,200.00    1677000     839900

# %%
#https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.sum.html need to set axis to 1 
df['total_adults_age_groups'] = df[total_adults_age_groups].sum(axis=1)
df.head(3)
# Out:
#   Location     Male   Female  Adults_with_Children  Adults_with_No_Children  \
# 0  Alabama  2284900  2456500                878300                  1941300
# 1   Alaska   364500   345600                153600                   283800
# 2  Arizona  3363200  3478100               1322700                  2646700
#
#      White        Black  Hispanic      Asian  \
# 0  3119100 1,259,900.00    195700  63,800.00
# 1   433000    18,000.00     47400  46,600.00
# 2  3761600   270,200.00   2143400 220,300.00
#
#    American_Indian_or_Alaska_Native  \
# 0                         19,800.00
# 1                         95,500.00
# 2                        261,300.00
#
#    Native_Hawaiian_or_Other_Pacific_Islander  Two_Or_More_Races  Age0_18  \
# 0                                        nan          81,800.00  1138300
# 1                                   6,300.00          63,300.00   192300
# 2                                  12,500.00         172,000.00  1686200
#
# ...

# %%
#annoying that calculated column all the way at the end redefine so at front of df
#https://erikrood.com/Python_References/change_order_dataframe_columns_final.html 
#basically just define a different order 
df.columns.to_list()
#new_order = df.columns.to_list()
new_col_order = ['Location',
 'total',
 'total_adults_age_groups',
 'Male',
 'Female',
 'Adults_with_Children',
 'Adults_with_No_Children',
 'White',
 'Black',
 'Hispanic',
 'Asian',
 'American_Indian_or_Alaska_Native',
 'Native_Hawaiian_or_Other_Pacific_Islander',
 'Two_Or_More_Races',
 'Age0_18',
 'Age_19_25',
 'Age_26_34',
 'Age_35_54',
 'Age_55_64',
 'Age_65_plus'
 ]

# %%
#need to reset pd display options 
pd.options.display.float_format = '{:,.0f}'.format #usually dont have a fraction of a person!

# %%
df[['Location',
 'total',
 'total_adults_age_groups',
 'Male',
 'Female',
 'Adults_with_Children',
 'Adults_with_No_Children',
 'White',
 'Black',
 'Hispanic',
 'Asian',
 'American_Indian_or_Alaska_Native',
 'Native_Hawaiian_or_Other_Pacific_Islander',
 'Two_Or_More_Races',
 'Age0_18',
 'Age_19_25',
 'Age_26_34',
 'Age_35_54',
 'Age_55_64',
 'Age_65_plus']
  ]
# Out:
#                 Location     total  total_adults_age_groups      Male  \
# 0                Alabama   4741400                2,819,500   2284900
# 1                 Alaska    710100                  437,400    364500
# 2                Arizona   6841300                3,969,300   3363200
# 3               Arkansas   2909900                1,698,700   1422700
# 4             California  38713800               23,936,900  19113000
# 5               Colorado   5461100                3,399,600   2723500
# 6            Connecticut   3478700                2,129,200   1692100
# 7               Delaware    931700                  553,400    448000
# 8   District of Columbia    657600                  450,500    309400
# 9                Florida  20532300               12,023,700   9960700
# 10               Georgia  10121500                6,136,500   4870800
# 11                Hawaii   1356100                  794,000    662300
# ...

# %%
#test the population difference for PA
df['adult_population_difference'] = df['total'] - df['total_adults_age_groups']
df.iloc[38]
# Out:
# Location                                     Pennsylvania
# Male                                              6049400
# Female                                            6339700
# Adults_with_Children                              2401800
# Adults_with_No_Children                           5042500
# White                                             9498700
# Black                                           1,294,800
# Hispanic                                           906500
# Asian                                             424,000
# American_Indian_or_Alaska_Native                   12,100
# Native_Hawaiian_or_Other_Pacific_Islander             NaN
# Two_Or_More_Races                                 249,900
# Age0_18                                           2746700
# Age_19_25                                         1028600
# Age_26_34                                       1,466,600
# Age_35_54                                         3152500
# ...

# %%
#nice but an array 
df[df['Location'] == 'Pennsylvania'][['adult_population_difference']].values
# Out:
# array([[4944800.]])

# %%
pa = df[df['Location'] == 'Pennsylvania'][['adult_population_difference']].values

# %%
#convert to value 
pa.item()
# Out:
# 4944800.0

# %%
pa = df[df['Location'] == 'Pennsylvania'][['adult_population_difference']].values
pa = pa.item()
co = df[df['Location'] == 'Colorado'][['adult_population_difference']].values
co = co.item()
ge = df[df['Location'] == 'Georgia'][['adult_population_difference']].values
ge = ge.item()
al = df[df['Location'] == 'Alaska'][['adult_population_difference']].values
al = al.item()
ca = df[df['Location'] == 'California'][['adult_population_difference']].values
ca = ca.item()
print('values :', pa,co,ge,al,ca)
# Out:
# values : 4944800.0 2061500.0 3985000.0 272700.0 14776900.0

# %%
print("The population difference for Pennsylvania :", pa)
print("The population difference for Colorado     :", co)
print("The population difference for Georgia      :", ge )
print("The population difference for Alaska       :", al)
print("The population difference for California   :", ca)
# Out:
# The population difference for Pennsylvania : 4944800.0
# The population difference for Colorado     : 2061500.0
# The population difference for Georgia      : 3985000.0
# The population difference for Alaska       : 272700.0
# The population difference for California   : 14776900.0

# %% [markdown]
# __A6:__ _(2 points)_ It seems that our hypothesis is correct for these three states. To make sure, we need to confirm that the differences between total_adults_age_groups column and summation of Adults_with_Children and Adults_with_No_Children for all the locations are zero. You can do that by looking in all the states' differences. Instead of that, create a logical rule (boolean mask) to return `False` if there is at least one non-zero value in the difference between `total_adults_age_groups` column and summation of `Adults_with_Children` and `Adults_with_No_Children`.

# %%
#see if the pop is zero for any of the columns
[df['adult_population_difference'] == 0]
# Out:
# [0     False
#  1     False
#  2     False
#  3     False
#  4     False
#  5     False
#  6     False
#  7     False
#  8     False
#  9     False
#  10    False
#  11    False
#  12    False
#  13    False
#  14    False
#  15    False
#  16    False
#  17    False
#  18    False
#  19    False
#  20    False
#  21    False
#  22    False
#  23    False
#  24    False
#  25    False
#  26    False
#  27    False
#  28    False
#  29    False
#  30    False
#  31    False
#  32    False
#  33    False
#  34    False
#  35    False
#  36    False
#  37    False
#  38    False
#  39    False
#  40    False
#  41    False
#  42    False
#  43    False
#  44    False
#  45    False
#  46    False
#  47    False
#  48    False
#  49    False
#  50    False
#  51    False
#  Name: adult_population_difference, dtype: bool]

# %%
#no rows meet the criteria 
df[df['adult_population_difference'] == 0]
# Out:
# Empty DataFrame
# Columns: [Location, Male, Female, Adults_with_Children, Adults_with_No_Children, White, Black, Hispanic, Asian, American_Indian_or_Alaska_Native, Native_Hawaiian_or_Other_Pacific_Islander, Two_Or_More_Races, Age0_18, Age_19_25, Age_26_34, Age_35_54, Age_55_64, Age_65_plus, total, total_adults_age_groups, adult_population_difference]
# Index: []
#
# [0 rows x 21 columns]

# %%
pd.Series(population_difference_df.adult_population_difference.values,index=population_difference_df.Location).to_dict()
# Out:
# {'Alabama': 1921900.0,
#  'Alaska': 272700.0,
#  'Arizona': 2872000.0,
#  'Arkansas': 1211200.0,
#  'California': 14776900.0,
#  'Colorado': 2061500.0,
#  'Connecticut': 1349500.0,
#  'Delaware': 378300.0,
#  'District of Columbia': 207100.0,
#  'Florida': 8508600.0,
#  'Georgia': 3985000.0,
#  'Hawaii': 562100.0,
#  'Idaho': 719300.0,
#  'Illinois': 4885600.0,
#  'Indiana': 2601800.0,
#  'Iowa': 1254200.0,
#  'Kansas': 1164700.0,
#  'Kentucky': 1727200.0,
#  'Louisiana': 1831300.0,
#  'Maine': 520200.0,
#  'Maryland': 2263700.0,
#  'Massachusetts': 2501100.0,
#  'Michigan': 3855900.0,
#  'Minnesota': 2153900.0,
#  'Mississippi': 1198000.0,
#  'Missouri': 2397600.0,
#  'Montana': 414700.0,
#  'Nebraska': 765100.0,
#  'Nevada': 1159100.0,
#  'New Hampshire': 490900.0,
#  'New Jersey': 3435800.0,
#  'New Mexico': 852500.0,
#  'New York': 7333300.0,
#  'North Carolina': 3982100.0,
#  'North Dakota': 282900.0,
#  'Ohio': 4543200.0,
#  'Oklahoma': 1576000.0,
#  'Oregon': 1598900.0,
# ...

# %% [markdown]
# __A7:__ _(3 points)_ It seems that our hypothesis is not correct for all the locations. We need to know what are the locations and the exact differences to see if it is due to rounding or there is a really significant difference. Create a dictionary and store locations (as `keys`) and the amount of difference between the population of adults obtained using the summation of two `Adults_with_Children` and `Adults_with_No_Children` columns and those obtained using the population of `Age_19_25`, `Age_26_34`, `Age_35_54`, `Age_55_64` age-groups (as `values`).

# %%
#https://www.geeksforgeeks.org/python-pandas-dataframe-to_dict/
population_difference_df = df[df['adult_population_difference'] != 0]
population_difference_df
# Out:
#                 Location      Male    Female  Adults_with_Children  \
# 0                Alabama   2284900   2456500                878300
# 1                 Alaska    364500    345600                153600
# 2                Arizona   3363200   3478100               1322700
# 3               Arkansas   1422700   1487200                602000
# 4             California  19113000  19600800               7955200
# 5               Colorado   2723500   2737600               1134700
# 6            Connecticut   1692100   1786600                694500
# 7               Delaware    448000    483700                167900
# 8   District of Columbia    309400    348200                 87200
# 9                Florida   9960700  10571600               3604800
# 10               Georgia   4870800   5250700               2101100
# 11                Hawaii    662300    693800                245300
# 12                 Idaho    842300    839800                360600
# ...

# %% [markdown]
# __A8.__ _(7 points)_ In this part, we are going to find the similarity of locations based on their races population distributions using _cosine similarity_. In cases where there is no population of one race for a location in the dataframe (the corresponding value is `NaN`), replace them with `zero` using the `.fillna()` method of `pandas`. Then, create a list and append to that each pair of locations with their similarity as a tuple, like: `(loc1, loc2, similarity value)`.

# %%
import numpy as np #needed for array mulitplication and dot product

# %%
#understanding similarity 
#https://skipperkongen.dk/2018/09/19/cosine-similarity-in-python/
#https://masongallo.github.io/machine/learning,/python/2016/07/29/cosine-similarity.html

# get the columns that 
race_columns= ['White', 'Black', 'Hispanic', 'Asian', 'American_Indian_or_Alaska_Native', \
                'Native_Hawaiian_or_Other_Pacific_Islander', 'Two_Or_More_Races']
print(race_columns)
# Out:
# ['White', 'Black', 'Hispanic', 'Asian', 'American_Indian_or_Alaska_Native', 'Native_Hawaiian_or_Other_Pacific_Islander', 'Two_Or_More_Races']

# %%
#get the rows of df 
df.shape[0]
# Out:
# 52

# %%
#get first array 
loc1 = np.array(df.loc[0,race_columns].fillna(0)) #use fillna to fix NaN values 
for i in loc1:
    print(i)
# Out:
# 3119100.0
# 1259900.0
# 195700.0
# 63800.0
# 19800.0
# 0.0
# 81800.0

# %%
#get second array 
loc2 = np.array(df.loc[1,race_columns].fillna(0)) #use fillna to fix NaN values 
loc2
# Out:
# array([433000.,  18000.,  47400.,  46600.,  95500.,   6300.,  63300.])

# %%
#cosines do dot product 
dot1 = loc1.dot(loc2)
dot1
# Out:
# 1392566600000.0

# %%
#cosines normalize 
norm = np.linalg.norm(loc1) * np.linalg.norm(loc2)
norm
# Out:
# 1527897293285.6758

# %%
#cosines similarity score 
sim = dot1 / norm 
sim
# Out:
# 0.9114268387800772

# %%
#make a function to do this - but performance? Maybe better in-line 
def cos_calc(loc1,loc2,df):
        loc1_ratio = np.array(df.loc[loc1,race_columns].fillna(0))
        loc2_ratio = np.array(df.loc[loc2,race_columns].fillna(0))
        sim_val = loc1_ratio.dot(loc2_ratio) / ((np.linalg.norm(loc1_ratio) * np.linalg.norm(loc2_ratio)))
        return sim_val

# %%
cos_calc(0,1,df)
# Out:
# 0.9114268387800772

# %%
#need to do a pair wise comparison 
for i in range(df.shape[0]):
    print(df.loc[i,'Location'])
    for j in range(df.shape[0]):
        print(df.loc[j,'Location'])
        #put the cosines math here
# Out:
# Alabama
# Alabama
# Alaska
# Arizona
# Arkansas
# California
# Colorado
# Connecticut
# Delaware
# District of Columbia
# Florida
# Georgia
# Hawaii
# Idaho
# Illinois
# Indiana
# Iowa
# Kansas
# Kentucky
# Louisiana
# Maine
# Maryland
# Massachusetts
# Michigan
# Minnesota
# Mississippi
# Missouri
# Montana
# Nebraska
# Nevada
# New Hampshire
# New Jersey
# New Mexico
# New York
# North Carolina
# North Dakota
# Ohio
# Oklahoma
# Oregon
# Pennsylvania
# Rhode Island
# South Carolina
# South Dakota
# Tennessee
# Texas
# Utah
# Vermont
# Virginia
# Washington
# West Virginia
# Wisconsin
# Wyoming
# Puerto Rico
# Alaska
# Alabama
# Alaska
# Arizona
# Arkansas
# California
# Colorado
# Connecticut
# Delaware
# District of Columbia
# Florida
# Georgia
# Hawaii
# Idaho
# Illinois
# Indiana
# Iowa
# Kansas
# Kentucky
# Louisiana
# Maine
# Maryland
# Massachusetts
# Michigan
# Minnesota
# Mississippi
# Missouri
# Montana
# Nebraska
# Nevada
# New Hampshire
# New Jersey
# New Mexico
# ...

# %%
#need to do a pair wise comparison 
sim_list = [] 
for i in range(df.shape[0]):
#    print(df.loc[i,'Location'])
    for j in range(df.shape[0]):
        print(df.loc[j,'Location'])
        sim_list.append((df.loc[i,'Location'],df.loc[j,'Location']))
print(sim_list)  #looks like repeats 
len(sim_list)
# Out:
# Alabama
# Alaska
# Arizona
# Arkansas
# California
# Colorado
# Connecticut
# Delaware
# District of Columbia
# Florida
# Georgia
# Hawaii
# Idaho
# Illinois
# Indiana
# Iowa
# Kansas
# Kentucky
# Louisiana
# Maine
# Maryland
# Massachusetts
# Michigan
# Minnesota
# Mississippi
# Missouri
# Montana
# Nebraska
# Nevada
# New Hampshire
# New Jersey
# New Mexico
# New York
# North Carolina
# North Dakota
# Ohio
# Oklahoma
# Oregon
# Pennsylvania
# Rhode Island
# South Carolina
# South Dakota
# Tennessee
# Texas
# Utah
# Vermont
# Virginia
# Washington
# West Virginia
# Wisconsin
# Wyoming
# Puerto Rico
# Alabama
# Alaska
# Arizona
# Arkansas
# California
# Colorado
# Connecticut
# Delaware
# District of Columbia
# Florida
# Georgia
# Hawaii
# Idaho
# Illinois
# Indiana
# Iowa
# Kansas
# Kentucky
# Louisiana
# Maine
# Maryland
# Massachusetts
# Michigan
# Minnesota
# Mississippi
# Missouri
# Montana
# Nebraska
# Nevada
# New Hampshire
# New Jersey
# New Mexico
# New York
# ...

# %%
#https://thispointer.com/python-pandas-how-to-convert-lists-to-a-dataframe/
# make list into df and check for duplicates 
states = pd.DataFrame(sim_list, columns = ['State1','State2']) 
states.duplicated(['State2']) #https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.duplicated.html
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2699     True
# 2700     True
# 2701     True
# 2702     True
# 2703     True
# Length: 2704, dtype: bool

# %%
sim_list = [] 
for i in range(df.shape[0]):
#    print("i=",df.loc[i,'Location'])
    for j in range(df.shape[0]):
#        print("j=",df.loc[j,'Location'])
        if i !=j :  #NEEDED to remove duplicates check lens below to verify
            #Need math back here or as a function call 
            sim_list.append((df.loc[i,'Location'],df.loc[j,'Location'],i)) 
            
#print(sim_list)  
len(sim_list)
2704-2652
# Out:
# 52

# %%
#
sim_list = [] 
for i in range(df.shape[0]):
#    print("i=",df.loc[i,'Location'])
    for j in range(df.shape[0]):
#        print("j=",df.loc[j,'Location'])
        if i !=j :  #NEEDED to remove duplicates check lens below to verify 
            #math as function call ... 
            sim_list.append((df.loc[i,'Location'],df.loc[j,'Location'],cos_calc(i,j,df)))
            
print(sim_list)
# Out:
# [('Alabama', 'Alaska', 0.9114268387800772), ('Alabama', 'Arizona', 0.8532153881652852), ('Alabama', 'Arkansas', 0.982778111554958), ('Alabama', 'California', 0.6910373396673632), ('Alabama', 'Colorado', 0.9181663981509594), ('Alabama', 'Connecticut', 0.9553103684194725), ('Alabama', 'Delaware', 0.9942087439512888), ('Alabama', 'District of Columbia', 0.8600337602418917), ('Alabama', 'Florida', 0.9251438820043797), ('Alabama', 'Georgia', 0.983733285870616), ('Alabama', 'Hawaii', 0.4266773857139479), ('Alabama', 'Idaho', 0.9265581661297341), ('Alabama', 'Illinois', 0.9626915658026344), ('Alabama', 'Indiana', 0.963493028315945), ('Alabama', 'Iowa', 0.9400898150890012), ('Alabama', 'Kansas', 0.9466816358199139), ('Alabama', 'Kentucky', 0.9578361229344373), ('Alabama', 'Louisiana', 0.9935406238636664), ('Alabama', 'Maine', 0.9309310956689741), ('Alabama', 'Maryland', 0.9797117035348595), ('Alabama', 'Massachusetts', 0.9518043913154132), ('Alabama', 'Michigan', 0.9786086627973689), ('Alaba
# ...

# %%
#add the math back into the loop

# %% [markdown]
# __A9.__ _(3 points)_ What are the two most and two least similar locations based on their races population?

# %%
#sort the sim_list out here

# %%
# sort similarity list
#https://stackoverflow.com/questions/3766633/how-to-sort-with-lambda-in-python
sorted_sim = sorted(sim_list, key=lambda x: x[2])
sorted_sim[:5]
# Out:
# [('West Virginia', 'Puerto Rico', 0.01950610252950971),
#  ('Puerto Rico', 'West Virginia', 0.01950610252950971),
#  ('Maine', 'Puerto Rico', 0.023924231089706444),
#  ('Puerto Rico', 'Maine', 0.023924231089706444),
#  ('Vermont', 'Puerto Rico', 0.025611308193450824)]

# %%
#top of the list 
sorted_sim[0] #top of the list
# Out:
# ('West Virginia', 'Puerto Rico', 0.01950610252950971)

# %%
#bottom of the list 
sorted_sim[-1]  #bottom of the list
# Out:
# ('Vermont', 'Maine', 0.9999496582673306)
